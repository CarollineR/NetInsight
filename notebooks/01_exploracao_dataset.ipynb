# %% [markdown]
# # NetInsight - Exploraçao Inicial do Dataset
#
# ## Sprint 1 - Exploração do Dataset
#
# ### Objetivo
#
# Conhecer a estrutura do dataset UNSW-NB15
#
# ### Dataset
#
# - Nome: UNSW_NB15_training-set.csv
# - Origem: UNSW Canberra Cyber
# - Localização: data/raw
#
# ### Autor
#
# Carolline Ramos

# %%
import panda as pd
